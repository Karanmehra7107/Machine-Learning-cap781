# %% [markdown]
# Paper Code : B
# Que. Apply following operations on hight and weight dataset:
# 1. Plot the outputs with respect to input and identify that the dataset is linear or nonlinear.
# Que. Normalize diabetes dataset using zed-score method. Also identify the first four highly
# correlated columns with the outcome column.
# 2. Print Maximum, minimum, and average Salaries.
# Que.3. Identify the missing values from diabetes dataset and take the appropriate actions
# against missing values.

# %%
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-43ebdf4f-9069-4d51-b9d8-abf863648966" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43ebdf4f-9069-4d51-b9d8-abf863648966">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('height and weight (1).csv')
df.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.describe()
# Out:
#           Height     Weight
# count  15.000000  15.000000
# mean    1.650667  62.078000
# std     0.114235   7.037515
# min     1.470000  52.210000
# 25%     1.560000  56.520000
# 50%     1.650000  61.290000
# 75%     1.740000  67.190000
# max     1.830000  74.460000

# %%
plt.scatter(df.Height, df.Weight, color='blue')
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['Height']]
Y = df['Weight']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
import numpy as np
plt.scatter(df.Height, df.Weight, color="blue")
plt.xlabel("Height")
plt.xlabel("Weight")
train_x=np.asanyarray(df[["Height"]])
plt.plot(train_x, lm.coef_*train_x + lm.intercept_,'-r')        ## ploting the graph

# %%
#Q1: The Graph shows the data set is linear goes with straight line

# %%
import numpy as np

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-941c92c5-05c3-4c62-89d8-8cd643891050" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-941c92c5-05c3-4c62-89d8-8cd643891050">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_csv('diabetes_missing_values.csv')
df1.tail()
# Out:
#      Pregnancies Glucose BloodPressure  SkinThickness Insulin   BMI  \
# 763           10     101            76             48     180  32.9
# 764            2     122            70             27       0  36.8
# 765            5     121            72             23     112  26.2
# 766            1     126            60              0       0  30.1
# 767            1      93            70             31       0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe()                        # Discrptive anlysis
# Out:
#           Height     Weight
# count  15.000000  15.000000
# mean    1.650667  62.078000
# std     0.114235   7.037515
# min     1.470000  52.210000
# 25%     1.560000  56.520000
# 50%     1.650000  61.290000
# 75%     1.740000  67.190000
# max     1.830000  74.460000

# %%
df1.isnull()                         # checking the null values
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df1.isnull().count()                    # display and count missing values
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
df1.values.any()
# Out:
# 6

# %%
df1.info()   # null data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    object
#  2   BloodPressure             767 non-null    object
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    object
#  5   BMI                       768 non-null    object
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 54.1+ KB

# %%
import seaborn as sns
from scipy import stats

# %%
df1.corr()                # EDA exploratory data anlysis
# Out:
#                           Pregnancies  SkinThickness  \
# Pregnancies                  1.000000      -0.081672
# SkinThickness               -0.081672       1.000000
# DiabetesPedigreeFunction    -0.033523       0.183928
# Age                          0.544341      -0.113970
# Outcome                      0.221898       0.074752
#
#                           DiabetesPedigreeFunction       Age   Outcome
# Pregnancies                              -0.033523  0.544341  0.221898
# SkinThickness                             0.183928 -0.113970  0.074752
# DiabetesPedigreeFunction                  1.000000  0.033561  0.173844
# Age                                       0.033561  1.000000  0.238356
# Outcome                                   0.173844  0.238356  1.000000

# %%
df1.corr().plot()                # Ploting corelation

# %%
sns.heatmap(df1.corr())            # More the darker higher te corelation

# %%
df1.replace("?", np.nan, inplace = True)
df1.head()                                          # converting special char '?' with 'nan' values
# Out:
#    Pregnancies Glucose BloodPressure  SkinThickness Insulin   BMI  \
# 0            6     148            72             35       0  33.6
# 1            1      85            66             29       0  26.6
# 2            8     183            64              0       0  23.3
# 3            1      89            66             23      94  28.1
# 4            0     137            40             35     168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df1.dropna(subset=["BloodPressure","Glucose"], axis=0)    # removing nan values
# Out:
#      Pregnancies Glucose BloodPressure  SkinThickness Insulin   BMI  \
# 0              6     148            72             35       0  33.6
# 1              1      85            66             29       0  26.6
# 2              8     183            64              0       0  23.3
# 3              1      89            66             23      94  28.1
# 4              0     137            40             35     168  43.1
# ..           ...     ...           ...            ...     ...   ...
# 763           10     101            76             48     180  32.9
# 764            2     122            70             27       0  36.8
# 765            5     121            72             23     112  26.2
# 766            1     126            60              0       0  30.1
# 767            1      93            70             31       0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# ...

# %%
Z = df1[['Glucose', 'BloodPressure', 'BMI', 'Age']]

# %%
featureset = df1[['Glucose', 'BloodPressure', 'BMI', 'Age']]

# %%
from sklearn.preprocessing import MinMaxScaler
x = featureset.values                         # returns a numpy array
min_max_scaler = MinMaxScaler()
feature_mtx = min_max_scaler.fit_transform(x)
Z = feature_mtx
feature_mtx [0:5]
# Out:
# array([[0.74371859, 0.59016393, 0.50074516, 0.48333333],
#        [0.42713568, 0.54098361, 0.39642325, 0.16666667],
#        [0.91959799, 0.52459016, 0.34724292, 0.18333333],
#        [0.44723618, 0.54098361, 0.41877794, 0.        ],
#        [0.68844221, 0.32786885, 0.64232489, 0.2       ]])

# %%
A = df["Weight"].min()
B= df["Weight"].max()
C = df["Weight"].mean()

# %%
print(A,B,C)               # min,max and mean values
# Out:
# 52.21 74.46 62.078
